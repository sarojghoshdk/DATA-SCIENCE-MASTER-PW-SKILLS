# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# ANSWER:- Flask is an API of Python that allows us to build up web-applications. It was developed by Armin Ronacher.
# Flask is a micro web framework for Python that provides a simple and flexible way to build web applications.Flask is known for its simplicity, minimalism, and ease of use, and it has become a popular choice for developers who want to build small to medium-sized web applications quickly and efficiently. Flask is based on WSGI(Web Server Gateway Interface) toolkit and Jinja2 template engine.

# %% [markdown]
# Here are some of the advantages of using Flask Framework:
#
# Lightweight and flexible: Flask is a lightweight framework that does not require any particular tools or libraries to run. It is flexible and allows developers to choose the tools and libraries they want to use in their project.
#
# Simple to use: Flask has a simple and easy-to-use API, which makes it easy for developers to learn and use. It provides a basic set of tools and features, which can be extended as needed.
#
# Extensible: Flask has a modular design, which means that it can be easily extended with various third-party libraries and plugins. This allows developers to add functionality to their application without having to write everything from scratch.
#
# Well-documented: Flask has a comprehensive and easy-to-read documentation that covers all aspects of the framework. It also has a large and active community of developers who contribute to its development and provide support to other users.
#
# Good for small to medium-sized projects: Flask is well-suited for building small to medium-sized web applications. It is not intended for large-scale applications, but it can be used for building prototypes, proof-of-concepts, and small-scale applications.
#
# Fast development: Flask allows developers to build web applications quickly and efficiently, which can save time and resources. It provides a simple and straightforward way to handle requests and responses, making it easy to get started with building web applications.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# ANSWER:-

# %% [markdown]
# ![1st.jpg](attachment:00cce981-2b6f-4454-b3af-99b6ed271186.jpg)

# %% [markdown]
# ![2.png](attachment:cd304642-4df1-4225-a6c3-e31e91685918.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# ANSWER:- App routing in Flask refers to the process of mapping URLs to view functions in a Flask application. Flask uses a decorator called @app.route to define routes and associate them with view functions.

# %% [markdown]
# Nowadays, the web frameworks provide routing technique so that user can remember the URLs. It is useful to access the web page directly without navigating from the Home page.

# %% [markdown]
# When a user requests a URL that matches a defined route in the Flask app, the corresponding view function is executed and its return value is sent back to the user as a response. Flask supports various HTTP methods like GET, POST, PUT, DELETE, etc., and we can specify which HTTP methods a route should respond to using the methods argument in the @app.route decorator.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
#
# --> Company Name: ABC Corporation
#
# --> Location: India
#
# --> Contact Detail: 999-999-9999
#
# Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# ![3rd.jpg](attachment:7efd7153-773e-496c-bab3-a12305bdef28.jpg)

# %% [markdown]
# ![4th.jpg](attachment:2b787bdf-16fe-40e2-ba0a-4f47c8456b7d.jpg)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
# ANSWER: -
#
# The url_for() function is used in Flask for URL building. It generates a URL for a given function that is decorated with the @app.route decorator.

# %% [markdown]
# ![5th.jpg](attachment:a66f0782-248d-4117-a996-3c27e2784980.jpg)

# %% [markdown]
# ![6th.jpg](attachment:7d2269ac-0b26-4937-a735-c0f56a5d0a0e.jpg)

# %% [markdown]
# In this example, we define two routes: one for the homepage and one for displaying a user profile. We then use the url_for() function to generate URLs for these routes. When we call url_for('index'), it generates a URL for the index() function, which is decorated with the route '/'. Similarly, when we call url_for('show_user_profile', username='username'), it generates a URL for the show_user_profile() function, which is decorated with the route '/user/<username>' and takes a parameter username.
#
# Note that we use the with app.test_request_context() block to create a test request context. This allows us to use the url_for() function outside of a request context, which is required for testing purposes. In a real Flask application, you can simply call url_for() within a request handler function or template.
