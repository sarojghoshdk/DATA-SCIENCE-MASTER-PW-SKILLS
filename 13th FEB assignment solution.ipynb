# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
#
# Note: Here Exception class refers to the base class for all the exceptions.

# %% [markdown]
# ANSWER:- In Python, we use the Exception class to create custom exceptions because it is the base class for all built-in exceptions. This means that by creating a subclass of the Exception class, we inherit all the features and behavior of the Exception class and can customize it to suit our needs.
#
#     The Exception class is the base class for all built-in exceptions in Python. When create a custom exception, we should inherit from the Exception class so that your custom exception is a subclass of the Exception class.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
import sys

# Define a function to print exception hierarchy
def print_exception_hierarchy(exc):
    # Print the name of the exception
    print(f"{exc.__name__}:")
    
    # Print the base classes of the exception
    if exc.__bases__:
        for base in exc.__bases__:
            print(f"  |-", end=" ")
            print_exception_hierarchy(base)
    else:
        print("  |-(base class)")

# Print the hierarchy of all built-in exceptions
for exc in sys.modules["builtins"].__dict__.values():
    if isinstance(exc, type) and issubclass(exc, BaseException):
        print_exception_hierarchy(exc)
        print()
# Out:
# BaseException:
#   |- object:
#   |-(base class)
#
# Exception:
#   |- BaseException:
#   |- object:
#   |-(base class)
#
# TypeError:
#   |- Exception:
#   |- BaseException:
#   |- object:
#   |-(base class)
#
# StopAsyncIteration:
#   |- Exception:
#   |- BaseException:
#   |- object:
#   |-(base class)
#
# StopIteration:
#   |- Exception:
#   |- BaseException:
#   |- object:
#   |-(base class)
#
# GeneratorExit:
#   |- BaseException:
#   |- object:
#   |-(base class)
#
# SystemExit:
#   |- BaseException:
#   |- object:
#   |-(base class)
#
# KeyboardInterrupt:
#   |- BaseException:
#   |- object:
#   |-(base class)
#
# ImportError:
#   |- Exception:
#   |- BaseException:
#   |- object:
#   |-(base class)
#
# ModuleNotFoundError:
#   |- ImportError:
#   |- Exception:
#   |- BaseException:
#   |- object:
#   |-(base class)
#
# OSError:
#   |- Exception:
#   |- BaseException:
#   |- object:
#   |-(base class)
#
# OSError:
#   |- Exception:
#   |- BaseException:
#   |- object:
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# ANSWER:- The ArithmeticError class is a subclass of the Exception class in Python, and it represents a class of errors related to arithmetic operations.Some common errors that are defined as subclasses of ArithmeticError include:
#
# OverflowError: This error is raised when a calculation produces a result that is too large to be represented as a number in Python. For example:

# %%
#example of overflow error

j = 5.0

for i in range(1, 1000):
        j = j**i
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[5], line 6
#       3 j = 5.0
#       5 for i in range(1, 1000):
# ----> 6         j = j**i
#
# OverflowError: (34, 'Numerical result out of range')

# %% [markdown]
# ZeroDivisionError: This error is raised when an attempt is made to divide a number by zero. For example:

# %%
# example of zerodevision error

a = 10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 # example of zerodevision error
# ----> 3 a = 10/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# ANSWER:- The LookupError class is a subclass of the Exception class in Python,Some common errors that are defined as subclasses of LookupError include:
#
# --> key error
#
# --> index error

# %% [markdown]
# KeyError: This error is raised when an attempt is made to access a dictionary element using a key that is not present in the dictionary. For example:

# %%
d = {"a" : 1 , "b" : 2}
print(d["c"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 d = {"a" : 1 , "b" : 2}
# ----> 2 print(d["c"])
#
# KeyError: 'c'

# %% [markdown]
# IndexError: This error is raised when an attempt is made to access a list element using an index that is outside the range of valid index for the list. For example:

# %%
l = [1,2,3]
print(l[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 l = [1,2,3]
# ----> 2 print(l[3])
#
# IndexError: list index out of range

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# ANSWER:- ImportError is a built-in exception in Python that is raised when an attempt to import a module fails. This can happen for a variety of reasons, such as:
#
# --> The module name is incorrect
#
# --> The module is not installed on the system
#
# --> The module is not in the search path
#
# --> A required dependency is missing

# %%
import ram
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import ram
#
# ModuleNotFoundError: No module named 'ram'

# %% [markdown]
# ModuleNotFoundError :- ModuleNotFoundError is a subclass of ImportError that was introduced in Python 3.6. It is raised when a module is not found in the Python Standard Library or in a specific package or location.

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %% [markdown]
# ANSWER:- Here are some best practices for exception handling in Python:
#
# --> Catch specific exceptions:- Rather than catching the generic Exception class, it is recommended to catch specific exceptions that you expect to occur in your code.
#
# --> Provide a proper error messages:- When raising or catching exceptions, it is helpful to include information about the error that has occurred. This can make it easier to diagnose and fix the problem.
#
# --> Always try to log your error:- It is better to log error and not using print the error message.
#
# --> Always avoid to write a multiple exception handling:- Use spefic exception handling which is required for programme.
#
# --> Document all the error
#
# --> Cleanup all the recources
